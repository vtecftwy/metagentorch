# %% [markdown]
# # Prediction on yellow fever simulated reads (no storage)

# %% [markdown]
# This is a a reference notebook for prediction inference on yellow fever simulated reads, using the CNN_Virus original model and saving predictions, probabilities and metadata in a sqlite database.
#
# - Simulated reads from an aligned file generated by ART Illumina simulator (`*.aln file`).
# - Uses the generator provided by `AlnFileReader.cnn_virus_input_generator` to read batches of simulates reads and their metadata.
# - Uses the `cnn_virus` model to predict the label and position probabilities and classes for each simreads.
# - Creates a prediction report save data for analysis.
#
# > **Note**:
# >
# >When an `*.aln` file counts a very large number of simulated reads, running a prediction on all of them is very time consuming. Therefore, we also provide a function `skip_existing_predictions` applied to the generator, which allows to skip all simulated reads down to the last simulated read for which a prediction was already saved into the database. This allows to build the database step by step.

# %% [markdown]
# # 1. Imports and setup environment

# %%
# Install required custom packages if not installed yet.
import importlib.util
if not importlib.util.find_spec('ecutilities'):
    print('installing package: `ecutilities`')
    ! pip install -qqU ecutilities
else:
    print('`ecutilities` already installed')
if not importlib.util.find_spec('metagentools'):
    print('installing package: `metagentools')
    ! pip install -qqU metagentools
else:
    print('`metagentools` already installed')
# Out:
# `ecutilities` already installed
# `metagentools` already installed

# %%
# Import all required packages
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import re
import shutil
import time

from datetime import datetime
from ecutilities.core import files_in_tree
from ecutilities.ipython import nb_setup
from functools import partial
from IPython.display import display, update_display, Markdown, HTML
from nbdev import show_doc
from pandas import HDFStore
from pathlib import Path
from pprint import pprint
from tqdm.notebook import tqdm, trange
from typing import List, Tuple, Dict, Any, Generator

# Setup the notebook for development
nb_setup()

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # or any {'0', '1', '2'}
import tensorflow as tf
from tensorflow.python.client import device_lib
from tensorflow.keras.models import load_model
print(f"Tensorflow version: {tf.__version__}\n")

from metagentools.cnn_virus.data import _base_hot_encode, strings_to_tensors
from metagentools.cnn_virus.data import split_kmer_into_50mers, combine_prediction_batch
from metagentools.cnn_virus.data import FastaFileReader, FastqFileReader, AlnFileReader
from metagentools.cnn_virus.data import OriginalLabels
from metagentools.cnn_virus.data import string_input_batch_to_tensors, split_kmer_batch_into_50mers
from metagentools.cnn_virus.architecture import create_model_original
from metagentools.core import ProjectFileSystem, TextFileBaseReader
# Out:
# Set autoreload mode
# Tensorflow version: 2.8.2

# %% [markdown]
# List all computing devices available on the machine

# %%
devices = device_lib.list_local_devices()
print('\nDevices:')
for d in devices:
    t = d.device_type
    name = d.physical_device_desc
    l = [item.split(':', 1) for item in name.split(', ')]
    name_attr = dict([x for x in l if len(x)==2])
    dev = name_attr.get('name', ' ')
    print(f"  - {t}  {d.name} {dev:25s}")
# Out:
# Devices:
#   - CPU  /device:CPU:0
#   - GPU  /device:GPU:0  NVIDIA GeForce GTX 1050

# %% [markdown]
# # 2. Setup paths to files

# %% [markdown]
# Key folders and system information

# %%
pfs = ProjectFileSystem()
pfs.info()
# Out:
# Running linux on local computer
# Device's home directory: /home/vtec
# Project file structure:
#  - Root ........ /home/vtec/projects/bio/metagentools
#  - Data Dir .... /home/vtec/projects/bio/metagentools/data
#  - Notebooks ... /home/vtec/projects/bio/metagentools/nbs

# %% [markdown]
# - `p2model`: path to file with saved original pretrained model
# - `p2virus_labels` path to file with virus names and labels mapping for original model

# %%
p2model = pfs.data / 'saved/cnn_virus_original/pretrained_model.h5'
assert p2model.is_file(), f"No file found at {p2model.absolute()}"

p2virus_labels = pfs.data / 'CNN_Virus_data/virus_name_mapping'
assert p2virus_labels.is_file(), f"No file found at {p2virus_labels.absolute()}"

# %% [markdown]
# Path to the simulated read we want to use

# %%
fnames = files_in_tree(pfs.data / 'ncbi/simreads/yf', pattern='69seq')
# Out:
# simreads
#   |--yf
#   |    |--single_69seq_150bp
#   |    |    |--single_69seq_150bp.fq (0)
#   |    |    |--single_69seq_150bp.aln (1)
#   |    |    |--single_69seq_150bp_list_reads.json (2)

# %%
file_stem = 'single_69seq_150bp'

p2aln = pfs.data / f"ncbi/simreads/yf/{file_stem[:-2] if file_stem[-1] in ['1', '2'] else file_stem}/{file_stem}.aln"
assert p2aln.exists()

aln = AlnFileReader(p2aln)
print(f"Reading alignment file: {p2aln.name}:\n")
for i, aln_read in enumerate(aln):
    pass
print(f"  - {i+1:,d} simulated reads in file '{p2aln.name}' from {len(aln.header['reference sequences'])} reference sequences.")

print('  - ART command: ',aln.header['command'])
print('  - Reference Sequences:')
print('     ','\n      '.join(aln.header['reference sequences']))
# Out:
# Reading alignment file: single_69seq_150bp.aln:
#
#   - 1,160,343 simulated reads in file 'single_69seq_150bp.aln' from 69 reference sequences.
#   - ART command:  /usr/bin/art_illumina -i /home/vtec/projects/bio/metagentools/data/ncbi/refsequences/yf/yf_2023_yellow_fever.fa -ss HS25 -l 150 -f 250 -o /home/vtec/projects/bio/metagentools/data/ncbi/simreads/yf/single_69seq_150bp/single_69seq_150bp -rs 1731415434
#   - Reference Sequences:
#       @SQ	11089:ncbi:1	1	AY968064	11089	ncbi	Angola_1971	10234
#       @SQ	11089:ncbi:2	2	U54798	11089	ncbi	Ivory_Coast_1982	10231
#       @SQ	11089:ncbi:3	3	DQ235229	11089	ncbi	Ethiopia_1961	10234
#       @SQ	11089:ncbi:4	4	AY572535	11089	ncbi	Gambia_2001	10231
#       @SQ	11089:ncbi:5	5	MF405338	11089	ncbi	Ghana_Hsapiens_1927	10231
#       @SQ	11089:ncbi:6	6	U21056	11089	ncbi	Senegal_1927	10231
#       @SQ	11089:ncbi:7	7	AY968065	11089	ncbi	Uganda_1948	10234
#       @SQ	11089:ncbi:8	8	JX898871	11089	ncbi	ArD114896_Senegal_1995	10231
#       @SQ	11089:ncbi:9	9	JX898872	11089	ncbi	Senegal_Aedes-aegypti_1995	10231
#       @SQ	11089:ncbi:10	10	GQ379163	11089	ncbi	Peru_Hsapiens_2007	10231
#       @SQ	11089:ncbi:11	11	DQ118157	11089	ncbi	Spain_Vaccine_2004	10231
#       @SQ	11089:ncbi:12	12	MF289572	11089	ncbi	Singapore_2017	10231
#       @SQ	11089:ncbi:13	13	KU978764	11089	ncbi	Sudan_Hsapiens_1941	10231
#       @SQ	11089:ncbi:14	14	JX898878	11089	ncbi	ArD181250_Senegal_2005	10231
#       @SQ	11089:ncbi:15	15	JX898879	11089	ncbi	ArD181676_Senegal_2005	10231
#       @SQ	11089:ncbi:16	16	JX898881	11089	ncbi	Senegal_Aedes_luteocephalus_2005	10231
#       @SQ	11089:ncbi:17	17	JX898880	11089	ncbi	ArD181564_Senegal_2005	10231
#       @SQ	11089:ncbi:18	18	JX898877	11089	ncbi	ArD181464_Senegal_2005	10231
#       @SQ	11089:ncbi:19	19	JX898876	11089	ncbi	Senegal_Aedes_fucifer_2001	10231
#       @SQ	11089:ncbi:20	20	KU978765	11089	ncbi	Guinea_Bissau_Hsapiens_1965	10231
#       @SQ	11089:ncbi:21	21	JX898870	11089	ncbi	Senegal_Ae_fucifer_1996	10231
#       @SQ	11089:ncbi:22	22	JX898868	11089	ncbi	isolate_HD117294_Senegal_1995	10231
#       @SQ	11089:ncbi:23	23	JX898875	11089	ncbi	Senegal_Aedes_fucifer_2000	10231
#       @SQ	11089:ncbi:24	24	JX898874	11089	ncbi	ArD149194_Senegal_2000	10231
#       @SQ	11089:ncbi:25	25	JX898873	11089	ncbi	ArD149214_Senegal_2000	10231
#       @SQ	11089:ncbi:26	26	MK292067	11089	ncbi	Netherlands_Hsapiens_Gambia_2018	10231
#       @SQ	11089:ncbi:27	27	MK457701	11089	ncbi	Nigeria_Hsapiens_2018	10231
#       @SQ	11089:ncbi:28	28	MN958078	11089	ncbi	Nigeria_Hsapiens_2018	10231
#       @SQ	11089:ncbi:29	29	JX898869	11089	ncbi	CotedIvoire_Ae_africanus_1973	10231
#       @SQ	11089:ncbi:30	30	KU978763	11089	ncbi	Nigeria_Hsapiens_1946	10231
#       @SQ	11089:ncbi:31	31	MF004382	11089	ncbi	Bolivia_Hsapiens_1999	10231
#       @SQ	11089:ncbi:32	32	JF912181	11089	ncbi	Brazil_Hsapiens_1983	10231
#       @SQ	11089:ncbi:33	33	JF912179	11089	ncbi	Brazil_Haemagogus_sp_1980	10231
#       @SQ	11089:ncbi:34	34	JF912183	11089	ncbi	Brazil_Hsapiens_1984	10231
#       @SQ	11089:ncbi:35	35	JF912182	11089	ncbi	Brazil_Hsapiens_1984	10231
#       @SQ	11089:ncbi:36	36	JF912188	11089	ncbi	Brazil_Hsapiens_2000	10231
#       @SQ	11089:ncbi:37	37	JF912190	11089	ncbi	Brazil_Hsapiens_2002	10231
#       @SQ	11089:ncbi:38	38	HM582851	11089	ncbi	TrinidadandTobago_Alouetta_seniculus_2009	10231
#       @SQ	11089:ncbi:39	39	KM388814	11089	ncbi	Venezuela_Portuguesa_Hsapiens_2005	10231
#       @SQ	11089:ncbi:40	40	KM388815	11089	ncbi	Venezuela_Apure_Aseniculus_2007	10231
#       @SQ	11089:ncbi:41	41	KM388818	11089	ncbi	Venezuela_Barinas_Aseniculus_2006	10231
#       @SQ	11089:ncbi:42	42	KM388817	11089	ncbi	Venezuela_Guarico_Allouetta_seniculus_2004	10231
#       @SQ	11089:ncbi:43	43	KM388816	11089	ncbi	Venezuela_Monagas_Asiniculus_2010	10231
#       @SQ	11089:ncbi:44	44	MH666058	11089	ncbi	Brazil_Sapajus_sp_2016	10234
#       @SQ	11089:ncbi:45	45	MK583152	11089	ncbi	Brazil_SaoPaulo_Hsapiens_2017	10231
#       @SQ	11089:ncbi:46	46	MK583166	11089	ncbi	Brazil_SaoPaulo_Hsapiens_2018	10231
#       @SQ	11089:ncbi:47	47	MK760660	11089	ncbi	Netherlands_brazil_2018	10231
#       @SQ	11089:ncbi:48	48	MK760665	11089	ncbi	Netherlands_Hsapiens-from-brazil_2018	10231
#       @SQ	11089:ncbi:49	49	MF370549	11089	ncbi	Brazil_monkey_2015	10231
#       @SQ	11089:ncbi:50	50	MF370535	11089	ncbi	Brazil_Allouatta_sp_2016	10231
#       @SQ	11089:ncbi:51	51	MF370533	11089	ncbi	Brazil_Hsapiens_2017	10231
#       @SQ	11089:ncbi:52	52	MK333805	11089	ncbi	Brazil_IlhaGrande_Sabethes_chloropterus_2018	10231
#       @SQ	11089:ncbi:53	53	MF370530	11089	ncbi	Brazil_Haemagogus-janthinomys_2017	10231
#       @SQ	11089:ncbi:54	54	MW960207	11089	ncbi	Yellow_fever_YF118_CAR_2018	10234
#       @SQ	11089:ncbi:55	55	JN620362	11089	ncbi	Uganda_Hsapiens_2010	10234
#       @SQ	11089:ncbi:56	56	KY495641	11089	ncbi	China_Hsapiens_2016	10234
#       @SQ	11089:ncbi:57	57	KU949599	11089	ncbi	shanghai_2016	10234
#       @SQ	11089:ncbi:58	58	MG589641	11089	ncbi	China_Hsapiens_2016	10234
#       @SQ	11089:ncbi:59	59	KX268355	11089	ncbi	China_Hsapiens_2016	10234
#       @SQ	11089:ncbi:60	60	KY587416	11089	ncbi	China_Hsapiens_2016	10234
#       @SQ	11089:ncbi:61	61	MH633692	11089	ncbi	China_Hsapiens_2016	10233
#       @SQ	11089:ncbi:62	62	MF004383	11089	ncbi	432429_S4_MF004383.1	10234
#       @SQ	11089:ncbi:63	63	MW960207	11089	ncbi	yp.bam from : MW960207.1	10234
#       @SQ	11089:ncbi:64	64	ON323052	11089	ncbi	Nigeria_2020	10231
#       @SQ	11089:ncbi:65	65	ON323053	11089	ncbi	Nigeria_2020	10195
#       @SQ	11089:ncbi:66	66	ON323054	11089	ncbi	Nigeria_2020	10231
#       @SQ	11089:ncbi:67	67	OM066735	11089	ncbi	VHF-21-014/GHA/Damongo/2021	10014
#       @SQ	11089:ncbi:68	68	OM066736	11089	ncbi	VHF-21-029/GHA/Daboya/2021	10231
#       @SQ	11089:ncbi:69	69	OM066737	11089	ncbi	VHF-21-037/GHA/Damongo/2021	10231

# %% [markdown]
# # 3. (Optional) Test each inference step

# %% [markdown]
# Let's test each steps to prepare model inputs, generate the prediction and all claculated metrics, using a small batch size:
# 1. create the generator using teh `.aln` file to yiel pairs of batches (metadata and reads strings) using `aln.cnn_virus_input_generator`
# 2. transform the batch of string reads into a base hot encoded tensor, using the preprocessing funtion `string_input_batch_to_tensors`
# 3. split each kmer read into (k-49) 50-mer reads to present to the model
# 4. evaluate the prediction
# 5. calculate the metrics and meta:
#     - accuracy = recall
#     - levenstein distance between 50-mer read predictions
#     - float successive score between 50-mer read probabilities
#     - true read position for the 150-mer read

# %%
show_doc(aln.cnn_virus_input_generator)
# Out:
# ---
#
# [source](https://github.com/vtecftwy/metagentools/blob/main/metagentools/cnn_virus/data.py#LNone){target="_blank" style="float:right; font-size:smaller"}
#
# ### AlnFileReader.cnn_virus_input_generator
#
# >      AlnFileReader.cnn_virus_input_generator (label:int=118, bs:int=32)
#
# *Create a generator yielding a metadata batch (dict) and a read batch (tensor of strings)
#
# The metadata dictionary contains lists of metadata for each read in the batch. For example:
# ```
# {
#     'readid': ['2591237:ncbi:1-40200','2591237:ncbi:1-40199','2591237:ncbi:1-40198', ...],
#     'refseqid': ['2591237:ncbi:1','2591237:ncbi:1','2591237:ncbi:1', ...],
#     'read_pos': [5, 6, 1, ...],
#     'refsource': ['ncbi', 'ncbi', 'ncbi', ...],
#     ...
# }
# ```*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | label | int | 118 | label for this batch (assuming all reads are from the same species) |
# | bs | int | 32 | batch size |
# | **Returns** | **tuple** |  | **dict of metadata list and tensor of strings** |

# %% [markdown]
# We need to define the model label for yellow fever and a batch size.

# %%
OriginalLabels().search(s='yellow')
# Out:
# Yellow_fever_virus. Label: 118

# %%
show_doc(string_input_batch_to_tensors)
# Out:
# ---
#
# [source](https://github.com/vtecftwy/metagentools/blob/main/metagentools/cnn_virus/data.py#LNone){target="_blank" style="float:right; font-size:smaller"}
#
# ### string_input_batch_to_tensors
#
# >      string_input_batch_to_tensors (b:tensorflow.python.framework.ops.Tensor,
# >                                     k:int=150)
#
# *Function converting a batch of bp strings into three tensors: (x_seqs, (y_labels, y_pos))
#
# Expects input strings to have the format: 'read sequence     label   position' where:
#
# - read sequence: a string of length k (kmer)
# - label: an integer between 0 and 186 representing the read virus label
# - position: an integer between 0 and 9 representing the read position in the genome*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | b | Tensor |  | batch of strings representing the inputs (kmer, label, position) |
# | k | int | 150 | maximum read length in the batch |

# %%
b = 2
true_label = 118

aln.reset_iterator()
for batch_meta, batch_reads in aln.cnn_virus_input_generator(bs=b, label=true_label):
    reads_kmer, (labels_kmer, positions_kmer) = string_input_batch_to_tensors(batch_reads, k=150)
    break

print('Review metadata batch yielded by the generator:')
print(f"  List of metadata keys:")
print('  -','\n  - '.join(batch_meta.keys()))
print(f"  'readid' included in this batch':", ', '.join(batch_meta['readid']))
print('\nReview batch of string reads yielded by the generator:')
print(f"  - Shape: {batch_reads.shape}")
print('\nReview the read kmer tensor after preprocessing:')
print(f"  - Shape: {reads_kmer.shape}")
print('\nReview ground truth tensors:')
print(f"  - Shape true label tensor:    {labels_kmer.shape}")
print(f"  - Shape true position tensor: {positions_kmer.shape}")
# Out:
# Review metadata batch yielded by the generator:
#   List of metadata keys:
#   - aln_start_pos
#   - readid
#   - readnb
#   - refseq_strand
#   - refseqid
#   - refseqnb
#   - refsource
#   - reftaxonomyid
#   - read_pos
#   'readid' included in this batch': 11089:ncbi:1-17000, 11089:ncbi:1-16999
#
# Review batch of string reads yielded by the generator:
#   - Shape: (2,)
#
# Review the read kmer tensor after preprocessing:
#   - Shape: (2, 150, 5)
#
# Review ground truth tensors:
#   - Shape true label tensor:    (2, 187)
#   - Shape true position tensor: (2, 10)

# %% [markdown]
# The model only accepts 50-mer reads, so we need to split kmer reads into 50mers. For each kmer read, k-49 50mer reads will be generated, by shifting a window of 50 nucleotides by 1 nucleotide at a time.

# %%
show_doc(split_kmer_batch_into_50mers)
# Out:
# ---
#
# [source](https://github.com/vtecftwy/metagentools/blob/main/metagentools/cnn_virus/data.py#LNone){target="_blank" style="float:right; font-size:smaller"}
#
# ### split_kmer_batch_into_50mers
#
# >      split_kmer_batch_into_50mers
# >                                    (kmer:tensorflow.python.framework.ops.Tenso
# >                                    r)
#
# *Converts a batch of k-mer reads into several 50-mer reads, by shifting the k-mer one base at a time.
#
# for a batch of `b` k-mer reads, returns a batch of `b - 49` 50-mer reads*
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | kmer | Tensor | tensor representing a batch of k-mer reads, after base encoding |

# %%
reads_50mer = split_kmer_batch_into_50mers(reads_kmer)
nb_50mer_per_kmer = reads_kmer.shape[1]-49 
nb_50mer_reads = (nb_50mer_per_kmer) * reads_kmer.shape[0]
assert reads_50mer.shape == (nb_50mer_reads, 50,5)

print(f"Each kmer is split into {nb_50mer_per_kmer} 50-mer reads. Total 50-mer reads in a batch: {nb_50mer_reads}")
print('\nReview the reads tensor:')
print(f"  - Shape kmer tensor:   {reads_kmer.shape}")
print(f"  - Shape 50-mer tensor: {reads_50mer.shape}")
# Out:
# Each kmer is split into 101 50-mer reads. Total 50-mer reads in a batch: 202
#
# Review the reads tensor:
#   - Shape kmer tensor:   (2, 150, 5)
#   - Shape 50-mer tensor: (202, 50, 5)

# %% [markdown]
# If all runs smoothly, our generator and preprocessing are working fine. We can run the prediction loop

# %% [markdown]
# # 4. Run the Loop

# %% [markdown]
# ## Utility Functions

# %%
def top_predictions(probs, n=5):
    """Returns the top n top predictions for each kmer read"""

    def top_n_most_frequent(preds, n=5):
        """Returns the top n most frequent predictions for each 50read"""
        # print(preds.shape)
        uniques, counts = np.unique(preds, return_counts=True)
        top_idx = np.argsort(counts)[-n:]
        return uniques.take(top_idx)

    top_preds_in_50mers = np.argsort(probs, axis=-1)[:, :, -n:]
    nb_kmers, nb_50mers, nb_lbls = top_preds_in_50mers.shape
    # print(top_preds_in_50mers.shape)
    top_preds_in_kmer = top_preds_in_50mers.reshape(nb_kmers,nb_50mers * nb_lbls)
    # print(top_preds_in_kmer.shape)

    return np.apply_along_axis(top_n_most_frequent, axis=1, arr=top_preds_in_kmer, n=n)

# %%
def count_successive_label_preds(label_probs_per_kmer):
    """Counts succcession of identical 50-mer predictions

    Returns:
    - label_preds_per_kmer is a tensor with the predicted label for each k-mer
    - flat_series is a list of one list per k-mer, providing all succession of identical predictions
    - series is a dictionary with:
        - keys equal to each of the possible labels
        - values as a list of the length of each succession of identical prediction for that label
    """
    b = label_probs_per_kmer.shape[0]
    k = 150
    series = []
    flat_series = []
    label_preds_per_kmer = tf.argmax(label_probs_per_kmer, axis=2)
    same_as_next = tf.roll(label_preds_per_kmer, shift=-1, axis=1) == label_preds_per_kmer
    same_as_previous = tf.roll(label_preds_per_kmer, shift=+1, axis=1) == label_preds_per_kmer
    xor = tf.bitwise.bitwise_xor(tf.cast(same_as_next, dtype=tf.int16), tf.cast(same_as_previous, dtype=tf.int16))
    for i in range(b):
        kmer_series_idxs = tf.range(k-49)[tf.cast(xor[i], dtype=tf.bool)]
        start_idxs = kmer_series_idxs[0::2]
        end_idxs = kmer_series_idxs[1::2]
        flat_series.append((end_idxs-start_idxs+1).numpy().tolist())
        kmer_series = {key: [] for key in range(187)}
        for s,e in zip(start_idxs, end_idxs):
            kmer_series[label_preds_per_kmer[i,s].numpy().item()].append((e-s+1).numpy().item())
        series.append(kmer_series)
    return label_preds_per_kmer, flat_series, series

# %%
def successive_preds_score(preds, flat_series, true_label=118):
    """score 
    Evaluate score S(preds, true_label) for a list or predictions and the target value:
        S = (C / N) * (1 + (M / N) * (1 - F / C))
        Where:
        - N is the total number of elements in the list
        - C is the count of elements equal to y
        - M is the maximum length of any continuous sequence of y in the list
        - F is the number of "fragments" or separate sequences of y in the list
    """
    b, k = preds.shape
    nb_50mer = k - 49
    preds = tf.cast(preds,dtype=tf.float32)
    N = tf.convert_to_tensor([nb_50mer] * b, dtype=tf.float32)
    C = tf.reduce_sum(tf.cast(preds == true_label, tf.float32), axis=1)
    C_safe = C + tf.convert_to_tensor([0.0001]*b, dtype=tf.float32)
    M = tf.convert_to_tensor([max(l) if len(l)>0 else 0 for l in flat_series], dtype=tf.float32)
    F = tf.convert_to_tensor([len(l) for l in flat_series], dtype=tf.float32)
    score = (C / N) * (1 + (M / N) * (1 - F / C_safe))
    return score

# %%
def probabilities_scores(probs, sequence_threshold=0.9, sequence_weight=0.3):
    """ Score the 50-mer probabilities for each reads as follows:

        - the ideal list is a list whose elements are all 1
        - a list with many elements close to 1 gets a good score
        - between two lists, with the same elements but in different orders, 
          the one with the longest sequence of numbers closed to 1 gets a better score 

    The score is evaluated as a combination of:
        - Average proximity of the probabilities to 1
        - A longest sequence bonus
        - Weighted scoring between the two metrics above
    How It Works?
        - Average proximity to 1: 
          This is simply the mean of all probabilities in the list. 
          It ensures that lists with many elements close to 1 get a good score.
        - Longest sequence bonus: 
          This part finds the longest continuous sequence of probabilities above a certain threshold (default 0.9). 
          It's then normalized by dividing by the list length.
        - Weighted scoring: 
          The final score is a weighted combination of the average proximity and the sequence bonus. 
          You can adjust the sequence_weight to give more or less importance to the sequence aspect.
    """
    
    b = probs.shape[0]
    k = 150
    nb_50mer = k - 49
    sequence_weight_tensor = tf.convert_to_tensor([sequence_weight]*b, dtype=tf.float32)

    # 1. Calculate average proximity to 1
    true_label_probs = probs[:, :, true_label] # get the probabilities for the true label
    base_score = tf.reduce_mean(true_label_probs, axis=1)

    # 2. Find the longest sequence of numbers above the threshold
    prob_above_threshold = tf.cast(true_label_probs>=sequence_threshold, dtype=tf.float32)

    flat_series = []
    same_as_next = tf.roll(prob_above_threshold, shift=-1, axis=1) == prob_above_threshold
    same_as_previous = tf.roll(prob_above_threshold, shift=+1, axis=1) == prob_above_threshold
    xor = tf.bitwise.bitwise_xor(tf.cast(same_as_next, dtype=tf.int16), tf.cast(same_as_previous, dtype=tf.int16))
    for i in range(b):
        kmer_series_idxs = tf.range(k-49)[tf.cast(xor[i], dtype=tf.bool)]
        start_idxs = kmer_series_idxs[0::2]
        end_idxs = kmer_series_idxs[1::2]
        flat_series.append((end_idxs-start_idxs+1).numpy().tolist())

    max_sequence_lengths = tf.convert_to_tensor([max(l) if len(l)>0 else 0 for l in flat_series], dtype=tf.float32)

    # Normalize the sequence bonus
    sequences_bonus = max_sequence_lengths / k

    # 3. Combine the scores with weighting
    final_scores = (tf.ones_like(base_score)-sequence_weight_tensor) * base_score + sequence_weight_tensor * sequences_bonus
    
    return final_scores

# %% [markdown]
# ## Define alignment file

# %%
fnames = files_in_tree(pfs.data / 'ncbi/simreads/yf', pattern='69seq')
# Out:
# simreads
#   |--yf
#   |    |--single_69seq_150bp
#   |    |    |--single_69seq_150bp.fq (0)
#   |    |    |--single_69seq_150bp.aln (1)

# %%
file_stem = 'single_69seq_150bp'

p2aln = pfs.data / f"ncbi/simreads/yf/{file_stem[:-2] if file_stem[-1] in ['1', '2'] else file_stem}/{file_stem}.aln"
assert p2aln.exists()

aln = AlnFileReader(p2aln)
print(f"Reading alignment file: '{p2aln.name}' (in {p2aln.parent})\n")
for i, aln_read in enumerate(aln):
    pass
nb_kmer_reads = i
print(f"  - {i+1:,d} simulated reads in file '{p2aln.name}' from {len(aln.header['reference sequences'])} reference sequences.")

print('  - ART command: ',aln.header['command'])
print('  - Reference Sequences:')
print('     ','\n      '.join(aln.header['reference sequences']))
# Out:
# Reading alignment file: 'single_69seq_150bp.aln' (in /home/vtec/projects/bio/metagentools/data/ncbi/simreads/yf/single_69seq_150bp)
#
#   - 1,160,343 simulated reads in file 'single_69seq_150bp.aln' from 69 reference sequences.
#   - ART command:  /usr/bin/art_illumina -i /home/vtec/projects/bio/metagentools/data/ncbi/refsequences/yf/yf_2023_yellow_fever.fa -ss HS25 -l 150 -f 250 -o /home/vtec/projects/bio/metagentools/data/ncbi/simreads/yf/single_69seq_150bp/single_69seq_150bp -rs 1731415434
#   - Reference Sequences:
#       @SQ	11089:ncbi:1	1	AY968064	11089	ncbi	Angola_1971	10234
#       @SQ	11089:ncbi:2	2	U54798	11089	ncbi	Ivory_Coast_1982	10231
#       @SQ	11089:ncbi:3	3	DQ235229	11089	ncbi	Ethiopia_1961	10234
#       @SQ	11089:ncbi:4	4	AY572535	11089	ncbi	Gambia_2001	10231
#       @SQ	11089:ncbi:5	5	MF405338	11089	ncbi	Ghana_Hsapiens_1927	10231
#       @SQ	11089:ncbi:6	6	U21056	11089	ncbi	Senegal_1927	10231
#       @SQ	11089:ncbi:7	7	AY968065	11089	ncbi	Uganda_1948	10234
#       @SQ	11089:ncbi:8	8	JX898871	11089	ncbi	ArD114896_Senegal_1995	10231
#       @SQ	11089:ncbi:9	9	JX898872	11089	ncbi	Senegal_Aedes-aegypti_1995	10231
#       @SQ	11089:ncbi:10	10	GQ379163	11089	ncbi	Peru_Hsapiens_2007	10231
#       @SQ	11089:ncbi:11	11	DQ118157	11089	ncbi	Spain_Vaccine_2004	10231
#       @SQ	11089:ncbi:12	12	MF289572	11089	ncbi	Singapore_2017	10231
#       @SQ	11089:ncbi:13	13	KU978764	11089	ncbi	Sudan_Hsapiens_1941	10231
#       @SQ	11089:ncbi:14	14	JX898878	11089	ncbi	ArD181250_Senegal_2005	10231
#       @SQ	11089:ncbi:15	15	JX898879	11089	ncbi	ArD181676_Senegal_2005	10231
#       @SQ	11089:ncbi:16	16	JX898881	11089	ncbi	Senegal_Aedes_luteocephalus_2005	10231
#       @SQ	11089:ncbi:17	17	JX898880	11089	ncbi	ArD181564_Senegal_2005	10231
#       @SQ	11089:ncbi:18	18	JX898877	11089	ncbi	ArD181464_Senegal_2005	10231
#       @SQ	11089:ncbi:19	19	JX898876	11089	ncbi	Senegal_Aedes_fucifer_2001	10231
#       @SQ	11089:ncbi:20	20	KU978765	11089	ncbi	Guinea_Bissau_Hsapiens_1965	10231
#       @SQ	11089:ncbi:21	21	JX898870	11089	ncbi	Senegal_Ae_fucifer_1996	10231
#       @SQ	11089:ncbi:22	22	JX898868	11089	ncbi	isolate_HD117294_Senegal_1995	10231
#       @SQ	11089:ncbi:23	23	JX898875	11089	ncbi	Senegal_Aedes_fucifer_2000	10231
#       @SQ	11089:ncbi:24	24	JX898874	11089	ncbi	ArD149194_Senegal_2000	10231
#       @SQ	11089:ncbi:25	25	JX898873	11089	ncbi	ArD149214_Senegal_2000	10231
#       @SQ	11089:ncbi:26	26	MK292067	11089	ncbi	Netherlands_Hsapiens_Gambia_2018	10231
#       @SQ	11089:ncbi:27	27	MK457701	11089	ncbi	Nigeria_Hsapiens_2018	10231
#       @SQ	11089:ncbi:28	28	MN958078	11089	ncbi	Nigeria_Hsapiens_2018	10231
#       @SQ	11089:ncbi:29	29	JX898869	11089	ncbi	CotedIvoire_Ae_africanus_1973	10231
#       @SQ	11089:ncbi:30	30	KU978763	11089	ncbi	Nigeria_Hsapiens_1946	10231
#       @SQ	11089:ncbi:31	31	MF004382	11089	ncbi	Bolivia_Hsapiens_1999	10231
#       @SQ	11089:ncbi:32	32	JF912181	11089	ncbi	Brazil_Hsapiens_1983	10231
#       @SQ	11089:ncbi:33	33	JF912179	11089	ncbi	Brazil_Haemagogus_sp_1980	10231
#       @SQ	11089:ncbi:34	34	JF912183	11089	ncbi	Brazil_Hsapiens_1984	10231
#       @SQ	11089:ncbi:35	35	JF912182	11089	ncbi	Brazil_Hsapiens_1984	10231
#       @SQ	11089:ncbi:36	36	JF912188	11089	ncbi	Brazil_Hsapiens_2000	10231
#       @SQ	11089:ncbi:37	37	JF912190	11089	ncbi	Brazil_Hsapiens_2002	10231
#       @SQ	11089:ncbi:38	38	HM582851	11089	ncbi	TrinidadandTobago_Alouetta_seniculus_2009	10231
#       @SQ	11089:ncbi:39	39	KM388814	11089	ncbi	Venezuela_Portuguesa_Hsapiens_2005	10231
#       @SQ	11089:ncbi:40	40	KM388815	11089	ncbi	Venezuela_Apure_Aseniculus_2007	10231
#       @SQ	11089:ncbi:41	41	KM388818	11089	ncbi	Venezuela_Barinas_Aseniculus_2006	10231
#       @SQ	11089:ncbi:42	42	KM388817	11089	ncbi	Venezuela_Guarico_Allouetta_seniculus_2004	10231
#       @SQ	11089:ncbi:43	43	KM388816	11089	ncbi	Venezuela_Monagas_Asiniculus_2010	10231
#       @SQ	11089:ncbi:44	44	MH666058	11089	ncbi	Brazil_Sapajus_sp_2016	10234
#       @SQ	11089:ncbi:45	45	MK583152	11089	ncbi	Brazil_SaoPaulo_Hsapiens_2017	10231
#       @SQ	11089:ncbi:46	46	MK583166	11089	ncbi	Brazil_SaoPaulo_Hsapiens_2018	10231
#       @SQ	11089:ncbi:47	47	MK760660	11089	ncbi	Netherlands_brazil_2018	10231
#       @SQ	11089:ncbi:48	48	MK760665	11089	ncbi	Netherlands_Hsapiens-from-brazil_2018	10231
#       @SQ	11089:ncbi:49	49	MF370549	11089	ncbi	Brazil_monkey_2015	10231
#       @SQ	11089:ncbi:50	50	MF370535	11089	ncbi	Brazil_Allouatta_sp_2016	10231
#       @SQ	11089:ncbi:51	51	MF370533	11089	ncbi	Brazil_Hsapiens_2017	10231
#       @SQ	11089:ncbi:52	52	MK333805	11089	ncbi	Brazil_IlhaGrande_Sabethes_chloropterus_2018	10231
#       @SQ	11089:ncbi:53	53	MF370530	11089	ncbi	Brazil_Haemagogus-janthinomys_2017	10231
#       @SQ	11089:ncbi:54	54	MW960207	11089	ncbi	Yellow_fever_YF118_CAR_2018	10234
#       @SQ	11089:ncbi:55	55	JN620362	11089	ncbi	Uganda_Hsapiens_2010	10234
#       @SQ	11089:ncbi:56	56	KY495641	11089	ncbi	China_Hsapiens_2016	10234
#       @SQ	11089:ncbi:57	57	KU949599	11089	ncbi	shanghai_2016	10234
#       @SQ	11089:ncbi:58	58	MG589641	11089	ncbi	China_Hsapiens_2016	10234
#       @SQ	11089:ncbi:59	59	KX268355	11089	ncbi	China_Hsapiens_2016	10234
#       @SQ	11089:ncbi:60	60	KY587416	11089	ncbi	China_Hsapiens_2016	10234
#       @SQ	11089:ncbi:61	61	MH633692	11089	ncbi	China_Hsapiens_2016	10233
#       @SQ	11089:ncbi:62	62	MF004383	11089	ncbi	432429_S4_MF004383.1	10234
#       @SQ	11089:ncbi:63	63	MW960207	11089	ncbi	yp.bam from : MW960207.1	10234
#       @SQ	11089:ncbi:64	64	ON323052	11089	ncbi	Nigeria_2020	10231
#       @SQ	11089:ncbi:65	65	ON323053	11089	ncbi	Nigeria_2020	10195
#       @SQ	11089:ncbi:66	66	ON323054	11089	ncbi	Nigeria_2020	10231
#       @SQ	11089:ncbi:67	67	OM066735	11089	ncbi	VHF-21-014/GHA/Damongo/2021	10014
#       @SQ	11089:ncbi:68	68	OM066736	11089	ncbi	VHF-21-029/GHA/Daboya/2021	10231
#       @SQ	11089:ncbi:69	69	OM066737	11089	ncbi	VHF-21-037/GHA/Damongo/2021	10231

# %%
print(f"'{aln.path.name}' used for prediction (in {aln.path.parent}).")
# Out:
# 'single_69seq_150bp.aln' used for prediction (in /home/vtec/projects/bio/metagentools/data/ncbi/simreads/yf/single_69seq_150bp).

# %% [markdown]
# ## Inference for all refsequences

# %% [markdown]
# Define refseqs selected for inference. By default this is all of the 69 sequences. In case the inference is interupted, select those sequences that were not inferred yet as selected_refseqs to avoid running the same inference again.

# %%
refseq_metadata = aln.parse_header_reference_sequences()

# selected_refseqs = list(refseq_metadata.keys())
selected_refseqs = [f"11089:ncbi:{i}" for i in [63, 64, 65, 66, 67, 68, 69]]

print(f"      {'refseqid':^15s}  {'Accession':^13s}  {'Description':^20s}")
print(f"      {'-'*15:^15s}  {'-'*10:^13s}  {'-'*20:^20s}")
for i,rsid in enumerate(selected_refseqs):
    print(f"{i+1:2d}.   {rsid:15s}  {refseq_metadata[rsid]['refseq_accession']:^13s}  {refseq_metadata[rsid]['organism']:^20s}")
# Out:
#          refseqid        Accession        Description
#       ---------------   ----------    --------------------
#  1.   11089:ncbi:63      MW960207     yp.bam from : MW960207.1
#  2.   11089:ncbi:64      ON323052         Nigeria_2020
#  3.   11089:ncbi:65      ON323053         Nigeria_2020
#  4.   11089:ncbi:66      ON323054         Nigeria_2020
#  5.   11089:ncbi:67      OM066735     VHF-21-014/GHA/Damongo/2021
#  6.   11089:ncbi:68      OM066736     VHF-21-029/GHA/Daboya/2021
#  7.   11089:ncbi:69      OM066737     VHF-21-037/GHA/Damongo/2021

# %% [markdown]
# Define the inference loop for one refseqid

# %%
def infer_one_refseq(
    refseqid:str,   # the id of the reference sequence from which reads were simulated
    aln,            # AlnFileReader object for the aln file containing all the reads
    params          # dictionary of parameters for the inference
    ) -> Tuple[tf.Tensor, List, tf.Tensor, tf.Tensor]: # label_probs_kmer, flat_series, preds_scores, probs_scores

    # Data parameters           
    b = params.get('b', 64)     # number of k-mer in a batch 850 5to cover half a set of one refseq (1700)
    k = params.get('k', 150)    # read length
    true_label = params.get('true_label', 118)  # yellow fever virus
    top_n = params.get('top_n', 5)              # n for top-n prediction to keep

    print(f"Run prediction loop with the following parameters:")
    print(f"   refseqid: {refseqid}")
    print(f"   {b} k-mer per batch; {k} bp per sequence; keep top-{top_n} predictions")

    # Inference loop parameters
    run_all_batches = params.get('run_all_batches', True)
    nb_batches_to_run = params.get('nb_batches_to_run', 2)

    #====================================================================================================
    # Setup prediction Loop
    #====================================================================================================
    nb_50mer = k - 49
    uid = datetime.today().strftime('%Y-%m-%d_%H_%M_%S')

    aln.reset_iterator()
    model = create_model_original(path2parameters=p2model)
    print(f"Model loaded and ready to run ...")

    # Create list of columns for prediction and probabilities reports
    pred_cols_str = 'readid refseqid refsource refseq_strand taxonomyid'.split(' ')
    pred_cols_int = 'lbl_true lbl_pred pos_true pos_pred'.split(' ')
    top_pred_cols = [f"top_{top_n}_lbl_pred_{i}" for i in range(top_n)]
    score_cols = ['preds_score', 'probs_score']

    # Storage parameters
    p2store = pfs.data / f"ncbi/infer_results/yf-ncbi/local-inf/{refseqid.replace(':','_')}.csv"
    p2store.unlink(missing_ok=True)
    with open(p2store, 'w') as f:
        f.write(','.join(pred_cols_str + pred_cols_int + top_pred_cols + score_cols) + '\n')

    def tprint(string):
        print(f"{datetime.now().strftime('%H:%M:%S')}    {string}")


    #====================================================================================================
    # Setup prediction Loop
    #====================================================================================================
    print(f"Run prediction loop with the following parameters:")
    print(f"   refseqid: {refseqid}")
    print(f"   {b} k-mer per batch; {k} bp per sequence; keep top-{top_n} predictions")
    tprint(f"Starting prediction loop ...")
    gen = aln.cnn_virus_input_generator(bs=b, label=true_label)

    # Proceed with prediction inference 
    label_probs_kmer, flat_series, preds_scores, probs_scores = None, None, None, None

    batch_nb = 0
    for i,(metadata_batch, reads_batch) in enumerate(gen):
        # skip any reference sequence not in the selected list
        any_selected_refseq_in_batch = any([rsid == refseqid for rsid in metadata_batch['refseqid']])
        if not any_selected_refseq_in_batch:
            tprint(f"Skipping batch {i+1:,d} because does not include any read from {refseqid}")
            continue
        batch_nb += 1
        loop_start = datetime.now()
        # tprint(f"Batch {i+1:3,d} (aln batch {nb_batches_skipped+i+1:3,d}) ...")

        reads_kmer, (labels_true, position_true) = string_input_batch_to_tensors(reads_batch, k=k)
        reads_50mer = split_kmer_batch_into_50mers(reads_kmer)
        assert reads_50mer.shape == ((reads_kmer.shape[1]-49) * b, 50, 5), f"Problem with shape in batch {i+1}: {reads_50mer.shape}"

        tprint(f'  Starting prediction for {b:,} kmer reads ...')
        label_probs, position_probs = model.predict(reads_50mer)

        tprint('  Reshaping predictions ...')
        label_probs_kmer = tf.reshape(label_probs, shape=(b,nb_50mer,-1))
        position_probs_kmer = tf.reshape(position_probs, shape=(b,nb_50mer,-1))

        tprint('  Combining predictions ...')
        combined_predictions = tf.map_fn(
            fn=combine_prediction_batch,
            elems=[label_probs_kmer, position_probs_kmer], 
            fn_output_signature=tf.int64
            )

        label_predictions = combined_predictions[:,0]
        position_predictions = combined_predictions[:,1]
        top_preds = top_predictions(label_probs_kmer, n=top_n)
        
        label_preds_per_kmer, flat_series, series = count_successive_label_preds(label_probs_kmer)
        preds_scores = successive_preds_score(label_preds_per_kmer, flat_series, true_label=true_label)
        probs_scores = probabilities_scores(label_probs_kmer)
        # Add results for current batch
        tprint('  Preparing prediction report ...')
        preds_report = np.concatenate(
            [
                np.expand_dims(np.array(metadata_batch['readid']), axis=1),         # readid 
                np.expand_dims(np.array(metadata_batch['refseqid']), axis=1),       # refseqid
                np.expand_dims(np.array(metadata_batch['refsource']), axis=1),      # refsource
                np.expand_dims(np.array(metadata_batch['refseq_strand']), axis=1),  # refseq_strand
                np.expand_dims(np.array(metadata_batch['reftaxonomyid']), axis=1),  # taxonomyid
                np.expand_dims(np.array([true_label]*b), axis=1),                   # lbl_true
                np.expand_dims(label_predictions, axis=1),                          # lbl_pred
                np.expand_dims(np.array(metadata_batch['aln_start_pos']), axis=1),  # pos_true
                np.expand_dims(position_predictions, axis=1),                       # pos_pred
                top_preds[:, ::-1],                                                 # top_5_lbl_pred_0, top_5_lbl_pred_1, top_5_lbl_pred_2, top_5_lbl_pred_3, top_5_lbl_pred_4
                np.expand_dims(preds_scores.numpy(), axis=1),                         # int_score
                np.expand_dims(probs_scores.numpy(), axis=1)                        # float_score
            ],
            axis=1
        )

        df_preds = pd.DataFrame(
            data=preds_report, 
            columns=pred_cols_str + pred_cols_int + top_pred_cols + score_cols
            )
        tprint('  Saving batch prediction report ...')
        df_preds.to_csv(p2store, mode='a', index=False, header=False)

        tprint(f"  Batch processing time: {(datetime.now() - loop_start).total_seconds():.2f} sec")
        if not run_all_batches and batch_nb >= nb_batches_to_run: 
            print('Stopping')
            break

    print(f"All batches done for {refseqid} ...")

    return label_probs_kmer, flat_series, preds_scores, probs_scores

# %% [markdown]
# Define the parameters and run the loop for all selected sequences.
#
# Inference report is saved in `data/ncbi/infer_results/yf-ncbi/local-inf/refseqid.csv`

# %%
params = {
        # Data parameters           
    'b': 850,           # number of k-mer in a batch 850 to cover half a set of one refseq (1700)
    'k': 150,           # read length
    'true_label': 118,  # yellow fever virus
    'top_n': 5,         # n for top-n prediction to keep
    'run_all_batches': True,
    'nb_batches_to_run': 3
}

for refseqid in selected_refseqs:
    print(refseqid)
    label_probs_kmer, flat_series, preds_scores, probs_scores = infer_one_refseq(refseqid, aln, params)
# Out:
# 11089:ncbi:63
# Run prediction loop with the following parameters:
#    refseqid: 11089:ncbi:63
#    850 k-mer per batch; 150 bp per sequence; keep top-5 predictions
# Creating CNN Model (Original)
# Loading parameters from pretrained_model.h5
# Created pretrained model
# Model loaded and ready to run ...
# Run prediction loop with the following parameters:
#    refseqid: 11089:ncbi:63
#    850 k-mer per batch; 150 bp per sequence; keep top-5 predictions
# 11:20:40    Starting prediction loop ...
# 11:20:40    Skipping batch 1 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 2 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 3 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 4 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 5 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 6 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 7 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 8 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 9 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 10 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 11 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 12 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 13 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 14 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 15 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 16 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 17 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 18 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 19 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 20 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 21 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 22 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 23 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 24 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 25 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 26 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 27 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 28 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 29 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 30 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 31 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 32 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 33 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 34 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 35 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 36 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 37 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 38 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 39 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 40 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 41 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 42 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 43 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 44 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 45 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 46 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 47 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 48 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 49 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 50 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 51 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 52 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 53 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 54 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 55 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 56 because does not include any read from 11089:ncbi:63
# 11:20:40    Skipping batch 57 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 58 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 59 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 60 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 61 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 62 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 63 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 64 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 65 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 66 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 67 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 68 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 69 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 70 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 71 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 72 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 73 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 74 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 75 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 76 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 77 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 78 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 79 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 80 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 81 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 82 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 83 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 84 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 85 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 86 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 87 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 88 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 89 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 90 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 91 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 92 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 93 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 94 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 95 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 96 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 97 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 98 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 99 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 100 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 101 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 102 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 103 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 104 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 105 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 106 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 107 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 108 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 109 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 110 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 111 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 112 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 113 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 114 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 115 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 116 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 117 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 118 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 119 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 120 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 121 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 122 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 123 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 124 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 125 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 126 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 127 because does not include any read from 11089:ncbi:63
# 11:20:41    Skipping batch 128 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 129 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 130 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 131 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 132 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 133 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 134 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 135 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 136 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 137 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 138 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 139 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 140 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 141 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 142 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 143 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 144 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 145 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 146 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 147 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 148 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 149 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 150 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 151 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 152 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 153 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 154 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 155 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 156 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 157 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 158 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 159 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 160 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 161 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 162 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 163 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 164 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 165 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 166 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 167 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 168 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 169 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 170 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 171 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 172 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 173 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 174 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 175 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 176 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 177 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 178 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 179 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 180 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 181 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 182 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 183 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 184 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 185 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 186 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 187 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 188 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 189 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 190 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 191 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 192 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 193 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 194 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 195 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 196 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 197 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 198 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 199 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 200 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 201 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 202 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 203 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 204 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 205 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 206 because does not include any read from 11089:ncbi:63
# 11:20:42    Skipping batch 207 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 208 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 209 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 210 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 211 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 212 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 213 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 214 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 215 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 216 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 217 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 218 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 219 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 220 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 221 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 222 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 223 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 224 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 225 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 226 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 227 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 228 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 229 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 230 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 231 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 232 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 233 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 234 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 235 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 236 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 237 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 238 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 239 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 240 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 241 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 242 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 243 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 244 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 245 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 246 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 247 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 248 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 249 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 250 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 251 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 252 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 253 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 254 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 255 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 256 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 257 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 258 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 259 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 260 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 261 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 262 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 263 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 264 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 265 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 266 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 267 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 268 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 269 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 270 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 271 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 272 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 273 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 274 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 275 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 276 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 277 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 278 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 279 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 280 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 281 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 282 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 283 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 284 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 285 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 286 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 287 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 288 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 289 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 290 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 291 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 292 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 293 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 294 because does not include any read from 11089:ncbi:63
# 11:20:43    Skipping batch 295 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 296 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 297 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 298 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 299 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 300 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 301 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 302 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 303 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 304 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 305 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 306 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 307 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 308 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 309 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 310 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 311 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 312 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 313 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 314 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 315 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 316 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 317 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 318 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 319 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 320 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 321 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 322 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 323 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 324 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 325 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 326 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 327 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 328 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 329 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 330 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 331 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 332 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 333 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 334 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 335 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 336 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 337 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 338 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 339 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 340 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 341 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 342 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 343 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 344 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 345 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 346 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 347 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 348 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 349 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 350 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 351 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 352 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 353 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 354 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 355 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 356 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 357 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 358 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 359 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 360 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 361 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 362 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 363 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 364 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 365 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 366 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 367 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 368 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 369 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 370 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 371 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 372 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 373 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 374 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 375 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 376 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 377 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 378 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 379 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 380 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 381 because does not include any read from 11089:ncbi:63
# 11:20:44    Skipping batch 382 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 383 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 384 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 385 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 386 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 387 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 388 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 389 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 390 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 391 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 392 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 393 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 394 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 395 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 396 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 397 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 398 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 399 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 400 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 401 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 402 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 403 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 404 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 405 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 406 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 407 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 408 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 409 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 410 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 411 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 412 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 413 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 414 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 415 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 416 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 417 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 418 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 419 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 420 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 421 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 422 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 423 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 424 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 425 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 426 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 427 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 428 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 429 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 430 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 431 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 432 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 433 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 434 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 435 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 436 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 437 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 438 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 439 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 440 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 441 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 442 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 443 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 444 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 445 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 446 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 447 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 448 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 449 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 450 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 451 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 452 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 453 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 454 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 455 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 456 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 457 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 458 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 459 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 460 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 461 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 462 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 463 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 464 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 465 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 466 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 467 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 468 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 469 because does not include any read from 11089:ncbi:63
# 11:20:45    Skipping batch 470 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 471 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 472 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 473 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 474 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 475 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 476 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 477 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 478 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 479 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 480 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 481 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 482 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 483 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 484 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 485 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 486 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 487 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 488 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 489 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 490 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 491 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 492 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 493 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 494 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 495 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 496 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 497 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 498 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 499 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 500 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 501 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 502 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 503 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 504 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 505 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 506 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 507 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 508 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 509 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 510 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 511 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 512 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 513 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 514 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 515 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 516 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 517 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 518 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 519 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 520 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 521 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 522 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 523 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 524 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 525 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 526 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 527 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 528 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 529 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 530 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 531 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 532 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 533 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 534 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 535 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 536 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 537 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 538 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 539 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 540 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 541 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 542 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 543 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 544 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 545 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 546 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 547 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 548 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 549 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 550 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 551 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 552 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 553 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 554 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 555 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 556 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 557 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 558 because does not include any read from 11089:ncbi:63
# 11:20:46    Skipping batch 559 because does not include any read from 11089:ncbi:63
# 11:20:47    Skipping batch 560 because does not include any read from 11089:ncbi:63
# 11:20:47    Skipping batch 561 because does not include any read from 11089:ncbi:63
# 11:20:47    Skipping batch 562 because does not include any read from 11089:ncbi:63
# 11:20:47    Skipping batch 563 because does not include any read from 11089:ncbi:63
# 11:20:47    Skipping batch 564 because does not include any read from 11089:ncbi:63
# 11:20:47    Skipping batch 565 because does not include any read from 11089:ncbi:63
# 11:20:47    Skipping batch 566 because does not include any read from 11089:ncbi:63
# 11:20:47    Skipping batch 567 because does not include any read from 11089:ncbi:63
# ...
# 14:11:54    Skipping batch 1,219 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,220 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,221 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,222 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,223 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,224 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,225 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,226 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,227 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,228 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,229 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,230 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,231 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,232 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,233 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,234 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,235 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,236 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,237 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,238 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,239 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,240 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,241 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,242 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,243 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,244 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,245 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,246 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,247 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,248 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,249 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,250 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,251 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,252 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,253 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,254 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,255 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,256 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,257 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,258 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,259 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,260 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,261 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,262 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,263 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,264 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,265 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,266 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,267 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,268 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,269 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,270 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,271 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,272 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,273 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,274 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,275 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,276 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,277 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,278 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,279 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,280 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,281 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,282 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,283 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,284 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,285 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,286 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,287 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,288 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,289 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,290 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,291 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,292 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,293 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,294 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,295 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,296 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,297 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,298 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,299 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,300 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,301 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,302 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,303 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,304 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,305 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,306 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,307 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,308 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,309 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,310 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,311 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,312 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,313 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,314 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,315 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,316 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,317 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,318 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,319 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,320 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,321 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,322 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,323 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,324 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,325 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,326 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,327 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,328 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,329 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,330 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,331 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,332 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,333 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,334 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,335 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,336 because does not include any read from 11089:ncbi:69
# 14:11:54    Skipping batch 1,337 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,338 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,339 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,340 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,341 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,342 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,343 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,344 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,345 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,346 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,347 because does not include any read from 11089:ncbi:69
# 14:11:55    Skipping batch 1,348 because does not include any read from 11089:ncbi:69
# 14:11:55      Starting prediction for 850 kmer reads ...
# 14:12:43      Reshaping predictions ...
# 14:12:43      Combining predictions ...
# 14:13:20      Preparing prediction report ...
# 14:13:20      Saving batch prediction report ...
# 14:13:20      Batch processing time: 85.23 sec
# 14:13:20      Starting prediction for 850 kmer reads ...
# 14:14:08      Reshaping predictions ...
# 14:14:08      Combining predictions ...
# 14:14:42      Preparing prediction report ...
# 14:14:42      Saving batch prediction report ...
# 14:14:42      Batch processing time: 82.59 sec
# 14:14:43      Starting prediction for 850 kmer reads ...
# 14:15:31      Reshaping predictions ...
# 14:15:31      Combining predictions ...
# 14:16:05      Preparing prediction report ...
# 14:16:05      Saving batch prediction report ...
# 14:16:05      Batch processing time: 82.15 sec
# 14:16:05      Starting prediction for 850 kmer reads ...
# 14:16:53      Reshaping predictions ...
# 14:16:53      Combining predictions ...
# 14:17:25      Preparing prediction report ...
# 14:17:25      Saving batch prediction report ...
# 14:17:25      Batch processing time: 79.94 sec
# 14:17:25      Starting prediction for 850 kmer reads ...
# 14:18:13      Reshaping predictions ...
# 14:18:13      Combining predictions ...
# 14:18:49      Preparing prediction report ...
# 14:18:49      Saving batch prediction report ...
# 14:18:49      Batch processing time: 84.28 sec
# 14:18:49      Starting prediction for 850 kmer reads ...
# 14:19:37      Reshaping predictions ...
# 14:19:37      Combining predictions ...
# 14:20:12      Preparing prediction report ...
# 14:20:12      Saving batch prediction report ...
# 14:20:12      Batch processing time: 83.26 sec
# 14:20:13      Starting prediction for 850 kmer reads ...
# 14:21:00      Reshaping predictions ...
# 14:21:00      Combining predictions ...
# 14:21:32      Preparing prediction report ...
# 14:21:32      Saving batch prediction report ...
# 14:21:32      Batch processing time: 79.68 sec
# 14:21:32      Starting prediction for 850 kmer reads ...
# 14:22:20      Reshaping predictions ...
# 14:22:20      Combining predictions ...
# 14:22:54      Preparing prediction report ...
# 14:22:54      Saving batch prediction report ...
# 14:22:54      Batch processing time: 82.44 sec
# 14:22:55      Starting prediction for 850 kmer reads ...
# 14:23:42      Reshaping predictions ...
# 14:23:42      Combining predictions ...
# 14:24:16      Preparing prediction report ...
# 14:24:16      Saving batch prediction report ...
# 14:24:16      Batch processing time: 82.21 sec
# 14:24:17      Starting prediction for 850 kmer reads ...
# 14:25:05      Reshaping predictions ...
# 14:25:05      Combining predictions ...
# 14:25:39      Preparing prediction report ...
# 14:25:39      Saving batch prediction report ...
# 14:25:39      Batch processing time: 82.75 sec
# 14:25:40      Starting prediction for 850 kmer reads ...
# 14:26:27      Reshaping predictions ...
# 14:26:27      Combining predictions ...
# 14:27:01      Preparing prediction report ...
# 14:27:01      Saving batch prediction report ...
# 14:27:01      Batch processing time: 82.02 sec
# 14:27:02      Starting prediction for 850 kmer reads ...
# 14:27:49      Reshaping predictions ...
# 14:27:49      Combining predictions ...
# 14:28:25      Preparing prediction report ...
# 14:28:25      Saving batch prediction report ...
# 14:28:25      Batch processing time: 83.68 sec
# 14:28:25      Starting prediction for 850 kmer reads ...
# 14:29:13      Reshaping predictions ...
# 14:29:13      Combining predictions ...
# 14:29:47      Preparing prediction report ...
# 14:29:47      Saving batch prediction report ...
# 14:29:47      Batch processing time: 81.79 sec
# 14:29:47      Starting prediction for 850 kmer reads ...
# 14:30:35      Reshaping predictions ...
# 14:30:35      Combining predictions ...
# 14:31:09      Preparing prediction report ...
# 14:31:09      Saving batch prediction report ...
# 14:31:09      Batch processing time: 82.09 sec
# 14:31:09      Starting prediction for 850 kmer reads ...
# 14:31:57      Reshaping predictions ...
# 14:31:57      Combining predictions ...
# 14:32:31      Preparing prediction report ...
# 14:32:31      Saving batch prediction report ...
# 14:32:31      Batch processing time: 82.14 sec
# 14:32:31      Starting prediction for 850 kmer reads ...
# 14:33:19      Reshaping predictions ...
# 14:33:19      Combining predictions ...
# 14:33:53      Preparing prediction report ...
# 14:33:53      Saving batch prediction report ...
# 14:33:53      Batch processing time: 82.01 sec
# 14:33:53      Starting prediction for 850 kmer reads ...
# 14:34:41      Reshaping predictions ...
# 14:34:41      Combining predictions ...
# 14:35:16      Preparing prediction report ...
# 14:35:16      Saving batch prediction report ...
# 14:35:16      Batch processing time: 83.33 sec
# All batches done for 11089:ncbi:69 ...

# %% [markdown]
# # 5. Verify inference reports

# %% [markdown]
# Check that each report file includes only inference for reads simulated from the one reference sequence.

# %%
p2reports = sorted([p for p in (pfs.data / 'ncbi/infer_results/yf-ncbi/local-inf').glob('*.csv') if not p.stem.endswith('-original')])
len(p2reports), p2reports[:3]
# Out:
# (69,
#  [Path('/home/vtec/projects/bio/metagentools/data/ncbi/infer_results/yf-ncbi/local-inf/11089_ncbi_1.csv'),
#   Path('/home/vtec/projects/bio/metagentools/data/ncbi/infer_results/yf-ncbi/local-inf/11089_ncbi_10.csv'),
#   Path('/home/vtec/projects/bio/metagentools/data/ncbi/infer_results/yf-ncbi/local-inf/11089_ncbi_11.csv')])

# %%
MODIFY_FILE = False

reports_to_modify = []
for p in p2reports:
    refseqid = p.stem.replace('_',':')
    df = pd.read_csv(p)
    to_modify = df.loc[df.refseqid!=refseqid]
    if len(to_modify)>0:
        reports_to_modify.append(p)
        if MODIFY_FILE:
            shutil.copy(p, p.parent/f"{p.stem}-original.csv")
            df = df.loc[df.refseqid==refseqid]
            df.to_csv(p, index=False)
        print(f"{refseqid:15s}: NOK {df.shape} {len(to_modify):,d} rows to modify {to_modify.refseqid.unique().tolist()}")
    else:
        print(f"{refseqid:15s}: OK  {df.shape}")
# Out:
# 11089:ncbi:1   : OK  (17000, 16)
# 11089:ncbi:10  : OK  (17000, 16)
# 11089:ncbi:11  : OK  (17000, 16)
# 11089:ncbi:12  : OK  (17000, 16)
# 11089:ncbi:13  : OK  (17000, 16)
# 11089:ncbi:14  : OK  (17000, 16)
# 11089:ncbi:15  : OK  (17000, 16)
# 11089:ncbi:16  : OK  (17000, 16)
# 11089:ncbi:17  : OK  (17000, 16)
# 11089:ncbi:18  : OK  (17000, 16)
# 11089:ncbi:19  : OK  (17000, 16)
# 11089:ncbi:2   : OK  (17000, 16)
# 11089:ncbi:20  : OK  (17000, 16)
# 11089:ncbi:21  : OK  (17000, 16)
# 11089:ncbi:22  : OK  (17000, 16)
# 11089:ncbi:23  : OK  (17000, 16)
# 11089:ncbi:24  : OK  (17000, 16)
# 11089:ncbi:25  : OK  (17000, 16)
# 11089:ncbi:26  : OK  (17000, 16)
# 11089:ncbi:27  : OK  (17000, 16)
# 11089:ncbi:28  : OK  (17000, 16)
# 11089:ncbi:29  : OK  (17000, 16)
# 11089:ncbi:3   : OK  (17000, 16)
# 11089:ncbi:30  : OK  (17000, 16)
# 11089:ncbi:31  : OK  (17000, 16)
# 11089:ncbi:32  : OK  (17000, 16)
# 11089:ncbi:33  : OK  (17000, 16)
# 11089:ncbi:34  : OK  (17000, 16)
# 11089:ncbi:35  : OK  (17000, 16)
# 11089:ncbi:36  : OK  (17000, 16)
# 11089:ncbi:37  : OK  (17000, 16)
# 11089:ncbi:38  : OK  (17000, 16)
# 11089:ncbi:39  : OK  (17000, 16)
# 11089:ncbi:4   : OK  (17000, 16)
# 11089:ncbi:40  : OK  (17000, 16)
# 11089:ncbi:41  : OK  (17000, 16)
# 11089:ncbi:42  : OK  (17000, 16)
# 11089:ncbi:43  : OK  (17000, 16)
# 11089:ncbi:44  : OK  (16779, 16)
# 11089:ncbi:45  : OK  (17000, 16)
# 11089:ncbi:46  : OK  (17000, 16)
# 11089:ncbi:47  : OK  (17000, 16)
# 11089:ncbi:48  : OK  (17000, 16)
# 11089:ncbi:49  : OK  (17000, 16)
# 11089:ncbi:5   : OK  (17000, 16)
# 11089:ncbi:50  : OK  (17000, 16)
# 11089:ncbi:51  : OK  (17000, 16)
# 11089:ncbi:52  : OK  (17000, 16)
# 11089:ncbi:53  : OK  (17000, 16)
# 11089:ncbi:54  : OK  (17000, 16)
# 11089:ncbi:55  : OK  (17000, 16)
# 11089:ncbi:56  : OK  (16731, 16)
# 11089:ncbi:57  : OK  (17000, 16)
# 11089:ncbi:58  : OK  (16740, 16)
# 11089:ncbi:59  : OK  (17000, 16)
# 11089:ncbi:6   : OK  (17000, 16)
# 11089:ncbi:60  : OK  (17000, 16)
# 11089:ncbi:61  : OK  (17000, 16)
# 11089:ncbi:62  : OK  (17000, 16)
# 11089:ncbi:63  : OK  (16487, 16)
# 11089:ncbi:64  : OK  (17000, 16)
# 11089:ncbi:65  : OK  (16750, 16)
# 11089:ncbi:66  : OK  (17000, 16)
# 11089:ncbi:67  : OK  (12747, 16)
# 11089:ncbi:68  : OK  (13388, 16)
# 11089:ncbi:69  : OK  (13628, 16)
# 11089:ncbi:7   : OK  (17000, 16)
# 11089:ncbi:8   : OK  (17000, 16)
# 11089:ncbi:9   : OK  (17000, 16)

# %% [markdown]
# # End of Section
